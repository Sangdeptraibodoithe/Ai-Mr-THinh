# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense, Dropout, Activation
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
drive.mount('/content/drive',force_remount=True)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

train=train_datagen.flow_from_directory('/content/drive/MyDrive/foodtrian/trian',
                                               target_size=(256,256),
                                               batch_size=32,
                                               class_mode ='categorical')
test=train_datagen.flow_from_directory('/content/drive/MyDrive/foodtrian/test',
                                               target_size=(256,256),
                                               batch_size=32,
                                               class_mode ='categorical')
# Out:
# Mounted at /content/drive
# Found 100 images belonging to 10 classes.
# Found 30 images belonging to 10 classes.

# %%
# Dat ten cho cac classes
classes = ['cachien', 'canhchua', 'com', 'hap', 'lau', 'my', 'nuong', 'thitchien', 'thitkho', 'xao']

# %%
model=Sequential()
#model CNN

# input
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
# 1
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
# 2
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
# 3
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
# output
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer = 'he_uniform'))
model.add(Dense(10,activation='Softmax'))

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping

opt = SGD(lr = 0.01, momentum = 0.9)
model.compile(optimizer = 'adam', loss ='categorical_crossentropy',metrics = ['accuracy'])
callbacks=[EarlyStopping(monitor='val_loss',patience=100)]
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history=model.fit(train, steps_per_epoch=len(train), batch_size = 64, epochs=100, validation_data=test, validation_steps=len(test),
                  callbacks=callbacks,
                  verbose = 1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 930ms/step - loss: 4.5144 - accuracy: 0.0900 - val_loss: 2.4884 - val_accuracy: 0.1000
# Epoch 2/100
# 4/4 [==============================] - 2s 563ms/step - loss: 2.4045 - accuracy: 0.1000 - val_loss: 2.3341 - val_accuracy: 0.0333
# Epoch 3/100
# 4/4 [==============================] - 2s 534ms/step - loss: 2.2888 - accuracy: 0.1200 - val_loss: 2.2605 - val_accuracy: 0.1333
# Epoch 4/100
# 4/4 [==============================] - 2s 560ms/step - loss: 2.2434 - accuracy: 0.1600 - val_loss: 2.2023 - val_accuracy: 0.2000
# Epoch 5/100
# 4/4 [==============================] - 2s 536ms/step - loss: 2.1521 - accuracy: 0.2600 - val_loss: 2.1289 - val_accuracy: 0.2000
# Epoch 6/100
# 4/4 [==============================] - 2s 564ms/step - loss: 2.0410 - accuracy: 0.2000 - val_loss: 2.0593 - val_accuracy: 0.2333
# Epoch 7/100
# 4/4 [==============================] - 2s 551ms/step - loss: 1.9079 - accuracy: 0.3000 - val_loss: 1.9018 - val_accuracy: 0.3333
# Epoch 8/100
# 4/4 [==============================] - 2s 535ms/step - loss: 1.7246 - accuracy: 0.3800 - val_loss: 1.9292 - val_accuracy: 0.4000
# Epoch 9/100
# 4/4 [==============================] - 2s 559ms/step - loss: 1.7613 - accuracy: 0.3800 - val_loss: 1.9823 - val_accuracy: 0.3000
# Epoch 10/100
# 4/4 [==============================] - 2s 536ms/step - loss: 1.6342 - accuracy: 0.4100 - val_loss: 2.1131 - val_accuracy: 0.3000
# Epoch 11/100
# 4/4 [==============================] - 2s 536ms/step - loss: 1.6382 - accuracy: 0.4100 - val_loss: 2.4083 - val_accuracy: 0.3000
# Epoch 12/100
# 4/4 [==============================] - 2s 726ms/step - loss: 1.9093 - accuracy: 0.4300 - val_loss: 2.0978 - val_accuracy: 0.2333
# Epoch 13/100
# 4/4 [==============================] - 2s 534ms/step - loss: 1.5557 - accuracy: 0.4300 - val_loss: 1.8930 - val_accuracy: 0.3333
# Epoch 14/100
# 4/4 [==============================] - 2s 555ms/step - loss: 1.4781 - accuracy: 0.4100 - val_loss: 1.7892 - val_accuracy: 0.3000
# Epoch 15/100
# 4/4 [==============================] - 2s 563ms/step - loss: 1.2187 - accuracy: 0.6000 - val_loss: 1.9855 - val_accuracy: 0.2000
# Epoch 16/100
# 4/4 [==============================] - 2s 728ms/step - loss: 1.3922 - accuracy: 0.4800 - val_loss: 2.0384 - val_accuracy: 0.3000
# Epoch 17/100
# 4/4 [==============================] - 2s 569ms/step - loss: 1.1591 - accuracy: 0.5700 - val_loss: 1.9202 - val_accuracy: 0.3667
# Epoch 18/100
# 4/4 [==============================] - 2s 584ms/step - loss: 1.0791 - accuracy: 0.6200 - val_loss: 2.0106 - val_accuracy: 0.4333
# Epoch 19/100
# 4/4 [==============================] - 2s 722ms/step - loss: 0.9939 - accuracy: 0.6800 - val_loss: 1.9439 - val_accuracy: 0.3000
# Epoch 20/100
# 4/4 [==============================] - 4s 876ms/step - loss: 0.9687 - accuracy: 0.6500 - val_loss: 1.9431 - val_accuracy: 0.4000
# Epoch 21/100
# 4/4 [==============================] - 2s 536ms/step - loss: 0.9969 - accuracy: 0.6700 - val_loss: 1.8362 - val_accuracy: 0.4000
# Epoch 22/100
# 4/4 [==============================] - 2s 560ms/step - loss: 0.8877 - accuracy: 0.6500 - val_loss: 1.9158 - val_accuracy: 0.3000
# Epoch 23/100
# 4/4 [==============================] - 2s 743ms/step - loss: 1.2741 - accuracy: 0.5100 - val_loss: 1.6575 - val_accuracy: 0.4667
# Epoch 24/100
# 4/4 [==============================] - 2s 564ms/step - loss: 0.9337 - accuracy: 0.6400 - val_loss: 2.0458 - val_accuracy: 0.3000
# Epoch 25/100
# 4/4 [==============================] - 2s 556ms/step - loss: 1.0228 - accuracy: 0.5800 - val_loss: 1.7921 - val_accuracy: 0.3333
# Epoch 26/100
# 4/4 [==============================] - 2s 726ms/step - loss: 0.8432 - accuracy: 0.7000 - val_loss: 1.9496 - val_accuracy: 0.3000
# Epoch 27/100
# 4/4 [==============================] - 2s 554ms/step - loss: 0.8856 - accuracy: 0.7100 - val_loss: 2.0958 - val_accuracy: 0.3333
# Epoch 28/100
# 4/4 [==============================] - 2s 723ms/step - loss: 0.7236 - accuracy: 0.7700 - val_loss: 2.0025 - val_accuracy: 0.3000
# Epoch 29/100
# 4/4 [==============================] - 2s 524ms/step - loss: 0.7197 - accuracy: 0.7600 - val_loss: 2.0774 - val_accuracy: 0.4333
# Epoch 30/100
# 4/4 [==============================] - 2s 716ms/step - loss: 0.4963 - accuracy: 0.8000 - val_loss: 1.9779 - val_accuracy: 0.4000
# Epoch 31/100
# 4/4 [==============================] - 2s 520ms/step - loss: 0.3884 - accuracy: 0.8800 - val_loss: 2.2036 - val_accuracy: 0.3667
# Epoch 32/100
# 4/4 [==============================] - 2s 713ms/step - loss: 0.2760 - accuracy: 0.9300 - val_loss: 2.4924 - val_accuracy: 0.4667
# Epoch 33/100
# 4/4 [==============================] - 2s 529ms/step - loss: 0.2650 - accuracy: 0.9200 - val_loss: 2.2911 - val_accuracy: 0.5000
# Epoch 34/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.3475 - accuracy: 0.8500 - val_loss: 2.4532 - val_accuracy: 0.5000
# Epoch 35/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.6143 - accuracy: 0.7700 - val_loss: 3.5342 - val_accuracy: 0.2667
# Epoch 36/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.5510 - accuracy: 0.8000 - val_loss: 2.1560 - val_accuracy: 0.4667
# Epoch 37/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.6275 - accuracy: 0.7500 - val_loss: 2.2480 - val_accuracy: 0.4667
# Epoch 38/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.6030 - accuracy: 0.7600 - val_loss: 2.3797 - val_accuracy: 0.3667
# Epoch 39/100
# 4/4 [==============================] - 2s 553ms/step - loss: 0.5354 - accuracy: 0.7800 - val_loss: 2.2708 - val_accuracy: 0.4333
# Epoch 40/100
# 4/4 [==============================] - 2s 525ms/step - loss: 0.4942 - accuracy: 0.8400 - val_loss: 2.4287 - val_accuracy: 0.4333
# Epoch 41/100
# 4/4 [==============================] - 2s 721ms/step - loss: 0.4681 - accuracy: 0.8200 - val_loss: 1.7904 - val_accuracy: 0.4000
# Epoch 42/100
# 4/4 [==============================] - 2s 553ms/step - loss: 0.3731 - accuracy: 0.8700 - val_loss: 1.9723 - val_accuracy: 0.4333
# Epoch 43/100
# 4/4 [==============================] - 2s 539ms/step - loss: 0.2395 - accuracy: 0.9500 - val_loss: 1.7716 - val_accuracy: 0.4333
# Epoch 44/100
# 4/4 [==============================] - 2s 520ms/step - loss: 0.2360 - accuracy: 0.9400 - val_loss: 1.7794 - val_accuracy: 0.5333
# Epoch 45/100
# 4/4 [==============================] - 2s 520ms/step - loss: 0.1859 - accuracy: 0.9200 - val_loss: 2.1225 - val_accuracy: 0.4333
# Epoch 46/100
# 4/4 [==============================] - 2s 528ms/step - loss: 0.1818 - accuracy: 0.9400 - val_loss: 1.9261 - val_accuracy: 0.5667
# Epoch 47/100
# 4/4 [==============================] - 2s 717ms/step - loss: 0.1116 - accuracy: 0.9600 - val_loss: 2.9886 - val_accuracy: 0.5333
# Epoch 48/100
# 4/4 [==============================] - 2s 726ms/step - loss: 0.0968 - accuracy: 0.9700 - val_loss: 3.4505 - val_accuracy: 0.4333
# Epoch 49/100
# 4/4 [==============================] - 2s 557ms/step - loss: 0.1684 - accuracy: 0.9300 - val_loss: 2.2297 - val_accuracy: 0.4667
# Epoch 50/100
# 4/4 [==============================] - 2s 731ms/step - loss: 0.1588 - accuracy: 0.9600 - val_loss: 2.4129 - val_accuracy: 0.5333
# Epoch 51/100
# 4/4 [==============================] - 2s 541ms/step - loss: 0.0841 - accuracy: 0.9800 - val_loss: 2.6515 - val_accuracy: 0.5000
# Epoch 52/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 2.6944 - val_accuracy: 0.5333
# Epoch 53/100
# 4/4 [==============================] - 2s 728ms/step - loss: 0.2143 - accuracy: 0.9200 - val_loss: 3.4140 - val_accuracy: 0.3333
# Epoch 54/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.2580 - accuracy: 0.9300 - val_loss: 2.6861 - val_accuracy: 0.5000
# Epoch 55/100
# 4/4 [==============================] - 2s 587ms/step - loss: 0.1442 - accuracy: 0.9400 - val_loss: 3.0340 - val_accuracy: 0.4667
# Epoch 56/100
# 4/4 [==============================] - 2s 585ms/step - loss: 0.1007 - accuracy: 0.9700 - val_loss: 2.3217 - val_accuracy: 0.4667
# Epoch 57/100
# 4/4 [==============================] - 2s 549ms/step - loss: 0.0529 - accuracy: 0.9900 - val_loss: 2.6592 - val_accuracy: 0.5667
# Epoch 58/100
# 4/4 [==============================] - 2s 536ms/step - loss: 0.0715 - accuracy: 0.9700 - val_loss: 2.5472 - val_accuracy: 0.5667
# Epoch 59/100
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0310 - accuracy: 0.9900 - val_loss: 2.3886 - val_accuracy: 0.4667
# Epoch 60/100
# 4/4 [==============================] - 2s 560ms/step - loss: 0.0708 - accuracy: 0.9700 - val_loss: 3.4117 - val_accuracy: 0.5000
# Epoch 61/100
# 4/4 [==============================] - 2s 534ms/step - loss: 0.3203 - accuracy: 0.9200 - val_loss: 3.7252 - val_accuracy: 0.4667
# Epoch 62/100
# 4/4 [==============================] - 2s 559ms/step - loss: 0.1579 - accuracy: 0.9700 - val_loss: 3.7069 - val_accuracy: 0.4333
# Epoch 63/100
# 4/4 [==============================] - 2s 557ms/step - loss: 0.1142 - accuracy: 0.9600 - val_loss: 3.5284 - val_accuracy: 0.4333
# Epoch 64/100
# 4/4 [==============================] - 2s 533ms/step - loss: 0.0766 - accuracy: 0.9700 - val_loss: 2.5607 - val_accuracy: 0.5000
# Epoch 65/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.0775 - accuracy: 0.9800 - val_loss: 2.4519 - val_accuracy: 0.6000
# Epoch 66/100
# 4/4 [==============================] - 2s 709ms/step - loss: 0.0664 - accuracy: 0.9900 - val_loss: 2.5520 - val_accuracy: 0.5333
# Epoch 67/100
# 4/4 [==============================] - 2s 525ms/step - loss: 0.0859 - accuracy: 0.9800 - val_loss: 2.6262 - val_accuracy: 0.4000
# Epoch 68/100
# 4/4 [==============================] - 2s 561ms/step - loss: 0.0287 - accuracy: 0.9900 - val_loss: 2.7537 - val_accuracy: 0.4667
# Epoch 69/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.0615 - accuracy: 0.9800 - val_loss: 2.8473 - val_accuracy: 0.4333
# Epoch 70/100
# 4/4 [==============================] - 2s 724ms/step - loss: 0.0651 - accuracy: 0.9700 - val_loss: 2.9230 - val_accuracy: 0.5000
# Epoch 71/100
# 4/4 [==============================] - 2s 523ms/step - loss: 0.0710 - accuracy: 0.9700 - val_loss: 3.4507 - val_accuracy: 0.5667
# Epoch 72/100
# 4/4 [==============================] - 2s 551ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 3.1313 - val_accuracy: 0.4000
# Epoch 73/100
# 4/4 [==============================] - 2s 720ms/step - loss: 0.0825 - accuracy: 0.9800 - val_loss: 2.7834 - val_accuracy: 0.5000
# Epoch 74/100
# 4/4 [==============================] - 2s 528ms/step - loss: 0.0201 - accuracy: 0.9900 - val_loss: 3.4335 - val_accuracy: 0.4333
# Epoch 75/100
# 4/4 [==============================] - 2s 531ms/step - loss: 0.0908 - accuracy: 0.9500 - val_loss: 3.3592 - val_accuracy: 0.4667
# Epoch 76/100
# 4/4 [==============================] - 2s 722ms/step - loss: 0.0578 - accuracy: 0.9800 - val_loss: 2.7185 - val_accuracy: 0.4333
# Epoch 77/100
# 4/4 [==============================] - 2s 730ms/step - loss: 0.0204 - accuracy: 0.9900 - val_loss: 3.1482 - val_accuracy: 0.4333
# Epoch 78/100
# 4/4 [==============================] - 2s 557ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 3.6075 - val_accuracy: 0.5000
# Epoch 79/100
# 4/4 [==============================] - 2s 527ms/step - loss: 0.0198 - accuracy: 0.9900 - val_loss: 4.2172 - val_accuracy: 0.4000
# Epoch 80/100
# 4/4 [==============================] - 2s 559ms/step - loss: 0.1978 - accuracy: 0.9600 - val_loss: 6.1115 - val_accuracy: 0.3000
# Epoch 81/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.5025 - accuracy: 0.8300 - val_loss: 2.9525 - val_accuracy: 0.4667
# Epoch 82/100
# 4/4 [==============================] - 2s 534ms/step - loss: 0.1128 - accuracy: 0.9600 - val_loss: 3.1677 - val_accuracy: 0.4667
# Epoch 83/100
# 4/4 [==============================] - 2s 530ms/step - loss: 0.2771 - accuracy: 0.9200 - val_loss: 2.8180 - val_accuracy: 0.5333
# Epoch 84/100
# 4/4 [==============================] - 2s 528ms/step - loss: 0.1134 - accuracy: 0.9700 - val_loss: 3.4538 - val_accuracy: 0.4667
# Epoch 85/100
# 4/4 [==============================] - 2s 557ms/step - loss: 0.1088 - accuracy: 0.9700 - val_loss: 3.4274 - val_accuracy: 0.4000
# Epoch 86/100
# 4/4 [==============================] - 2s 560ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 2.8850 - val_accuracy: 0.4667
# Epoch 87/100
# 4/4 [==============================] - 2s 530ms/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 2.8805 - val_accuracy: 0.4667
# Epoch 88/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.1963 - accuracy: 0.9600 - val_loss: 3.7339 - val_accuracy: 0.5000
# Epoch 89/100
# 4/4 [==============================] - 2s 555ms/step - loss: 0.0845 - accuracy: 0.9700 - val_loss: 3.5538 - val_accuracy: 0.4333
# Epoch 90/100
# 4/4 [==============================] - 2s 727ms/step - loss: 0.0457 - accuracy: 0.9800 - val_loss: 3.7932 - val_accuracy: 0.4667
# Epoch 91/100
# 4/4 [==============================] - 2s 719ms/step - loss: 0.0667 - accuracy: 0.9800 - val_loss: 2.9620 - val_accuracy: 0.5333
# Epoch 92/100
# 4/4 [==============================] - 2s 521ms/step - loss: 0.0849 - accuracy: 0.9800 - val_loss: 2.6937 - val_accuracy: 0.5000
# Epoch 93/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.0362 - accuracy: 0.9900 - val_loss: 2.3626 - val_accuracy: 0.5667
# Epoch 94/100
# 4/4 [==============================] - 2s 552ms/step - loss: 0.0457 - accuracy: 0.9900 - val_loss: 2.3879 - val_accuracy: 0.5333
# Epoch 95/100
# 4/4 [==============================] - 2s 555ms/step - loss: 0.0558 - accuracy: 0.9900 - val_loss: 3.5868 - val_accuracy: 0.3667
# Epoch 96/100
# 4/4 [==============================] - 2s 532ms/step - loss: 0.1642 - accuracy: 0.9500 - val_loss: 2.7950 - val_accuracy: 0.5333
# Epoch 97/100
# 4/4 [==============================] - 2s 556ms/step - loss: 0.1024 - accuracy: 0.9700 - val_loss: 2.9851 - val_accuracy: 0.5333
# Epoch 98/100
# 4/4 [==============================] - 2s 553ms/step - loss: 0.0644 - accuracy: 0.9800 - val_loss: 3.2272 - val_accuracy: 0.5000
# Epoch 99/100
# 4/4 [==============================] - 2s 553ms/step - loss: 0.0235 - accuracy: 0.9900 - val_loss: 3.2733 - val_accuracy: 0.5000
# Epoch 100/100
# 4/4 [==============================] - 2s 550ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 2.5271 - val_accuracy: 0.5333

# %%
model.save('food_CNN.h5')

# %%
from keras.models import load_model
models = load_model('food_CNN.h5')

# %%
score = model.evaluate(test,verbose=1)
print('Test loss= ', score[0])
print('Test accuracy= ', score[1])
# Out:
# 1/1 [==============================] - 1s 535ms/step - loss: 3.1449 - accuracy: 0.4667
# Test loss=  3.1449263095855713
# Test accuracy=  0.46666666865348816

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper left')

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img('/content/comm2.jpg',target_size=(256,256))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,256,256,3)
img=img.astype('float32')
img = img/255
print(classes[np.argmax(model.predict(img))])
# Out:
# com

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img('/content/nn5.jpg',target_size=(256,256))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,256,256,3)
img=img.astype('float32')
img = img/255
print(classes[np.argmax(model.predict(img))])
# Out:
# nuong

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img('/content/nn6.jpg',target_size=(256,256))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,256,256,3)
img=img.astype('float32')
img = img/255
print(classes[np.argmax(model.predict(img))])
# Out:
# thitchien

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img('/content/myy.jpg',target_size=(256,256))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,256,256,3)
img=img.astype('float32')
img = img/255
print(classes[np.argmax(model.predict(img))])

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img('/content/coooom.jpg',target_size=(256,256))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,256,256,3)
img=img.astype('float32')
img = img/255
print(classes[np.argmax(model.predict(img))])
# Out:
# com
